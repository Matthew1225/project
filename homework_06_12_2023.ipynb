# %%
import pandas as pd

# %%
df = pd.read_csv("School_Shootings_USA.csv")

# %% [markdown]
# # Q1. Show first 10 rows of dataset

# %%
df.head(10)
# Out:
#    Incident ID Incident Date           State                City Or County  \
# 0      2241994    25/02/2022  North Carolina                     Charlotte
# 1      2241810    25/02/2022         Florida                     Niceville
# 2      2242123    25/02/2022         Florida                         Miami
# 3      2245393    28/02/2022      California                      Stockton
# 4      2243754    28/02/2022  North Carolina                       Parkton
# 5      2243658    28/02/2022          Nevada                          Reno
# 6      2243833    28/02/2022        New York                      Brooklyn
# 7      2244462    01/03/2022           Texas                   Colleyville
# 8      2244265    01/03/2022         Florida  Land O Lakes (Land O' Lakes)
# 9      2245542    02/03/2022  North Carolina                     Charlotte
#
#                   Address            Business/Location Name  Victims Killed  \
# ...

# %% [markdown]
# # Q2. Show 10 last rows of dataset

# %%
df.tail(10)
# Out:
#       Incident ID Incident Date      State   City Or County  \
# 1990      2750851    07/11/2023   Virginia       Blacksburg
# 1991      2753938    13/11/2023      Texas     Prairie View
# 1992      2443879    24/10/2022   Missouri      Saint Louis
# 1993      2482288    16/12/2022   Illinois          Chicago
# 1994      2509254    23/01/2023       Iowa       Des Moines
# 1995      2618358    06/06/2023   Virginia         Richmond
# 1996      2459150    13/11/2022   Virginia  Charlottesville
# 1997      2524577    13/02/2023   Michigan     East Lansing
# 1998      2555459    27/03/2023  Tennessee        Nashville
# 1999      2310278    24/05/2022      Texas           Uvalde
#
#                          Address  \
# 1990    723 University City Blvd
# 1991  200 block of E M Norris St
# 1992    3125 S Kingshighway Blvd
# 1993            2150 S Laflin St
# 1994             455 SW Fifth St
# 1995               6 N Laurel St
# 1996             130 Culbreth St
# ...

# %% [markdown]
# ### Q3. How many columns this dataset has?

# %%
df.shape[1]
# Out:
# 11

# %% [markdown]
# ### Q4. How many rows are in this dataset?

# %%
df.shape[0]
# Out:
# 2000

# %% [markdown]
# ### Q5. How much unique values do State column have?

# %%
len(df.State.unique())
# Out:
# 51

# %% [markdown]
# ### Q6. Which state has the highest number of victims killed?

# %%
df.groupby('State')['Victims Killed'].count()
# Out:
# State
# Alabama                  58
# Alaska                    6
# Arizona                  40
# Arkansas                 29
# California               95
# Colorado                 23
# Connecticut               7
# Delaware                  9
# District of Columbia      8
# Florida                 141
# Georgia                 103
# Hawaii                    1
# Idaho                     3
# Illinois                 60
# Indiana                  70
# Iowa                     11
# Kansas                   18
# Kentucky                 57
# Louisiana                41
# Maine                     5
# Maryland                 74
# Massachusetts            17
# Michigan                 53
# Minnesota                35
# Mississippi              26
# Missouri                 30
# Montana                   1
# Nebraska                 12
# Nevada                   32
# New Hampshire             2
# New Jersey               11
# New Mexico               25
# New York                 40
# ...

# %% [markdown]
# Answer is Texas

# %% [markdown]
# ### Q7. In which State was the maximum number of suspects arrested?

# %%
df.groupby('State')['Suspects Arrested'].count()
# Out:
# State
# Alabama                  58
# Alaska                    6
# Arizona                  40
# Arkansas                 29
# California               95
# Colorado                 23
# Connecticut               7
# Delaware                  9
# District of Columbia      8
# Florida                 141
# Georgia                 103
# Hawaii                    1
# Idaho                     3
# Illinois                 60
# Indiana                  70
# Iowa                     11
# Kansas                   18
# Kentucky                 57
# Louisiana                41
# Maine                     5
# Maryland                 74
# Massachusetts            17
# Michigan                 53
# Minnesota                35
# Mississippi              26
# Missouri                 30
# Montana                   1
# Nebraska                 12
# Nevada                   32
# New Hampshire             2
# New Jersey               11
# New Mexico               25
# New York                 40
# ...

# %% [markdown]
# ### Q8. Describe the dataframe

# %%
df.describe()
# Out:
#         Incident ID  Victims Killed  Victims Injured  Suspects Killed  \
# count  2.000000e+03     2000.000000      2000.000000      2000.000000
# mean   2.506427e+06        0.052500         0.122000         0.009000
# std    1.430023e+05        0.533747         0.605227         0.094464
# min    2.241810e+06        0.000000         0.000000         0.000000
# 25%    2.414790e+06        0.000000         0.000000         0.000000
# 50%    2.505286e+06        0.000000         0.000000         0.000000
# 75%    2.596520e+06        0.000000         0.000000         0.000000
# max    2.765572e+06       21.000000        17.000000         1.000000
#
#        Suspects Injured  Suspects Arrested
# count       2000.000000        2000.000000
# mean           0.013000           0.855000
# std            0.129767           0.692253
# min            0.000000           0.000000
# 25%            0.000000           0.000000
# 50%            0.000000           1.000000
# ...

# %% [markdown]
# ### Q9. Show incidents Id of incidents that happened in Texas

# %%
df['Incident ID'][df['State'] == 'Texas']
# Out:
# 7       2244462
# 28      2250512
# 65      2261867
# 66      2263264
# 73      2265991
#          ...
# 1970    2682459
# 1983    2728346
# 1984    2730430
# 1991    2753938
# 1999    2310278
# Name: Incident ID, Length: 177, dtype: int64

# %% [markdown]
# ### Q10. Show all the amount of victims killed

# %%
df['Victims Killed'].sum()
# Out:
# 105
